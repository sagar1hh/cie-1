# %% [markdown]
# <a href="https://colab.research.google.com/github/sagar1hh/cie-1/blob/main/cie3_exicute.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
housing = fetch_california_housing()

df=pd.DataFrame(data=housing.data, columns=housing.feature_names)
df['PRICE'] = housing.target
print(df)

df.info()
df.head()
df.describe()


df.isnull().sum()




numeric_means = df.select_dtypes(include=['number']).mean()
df2 = df.fillna(numeric_means)
df2.isnull().sum()


X = pd.DataFrame(np.c_[df['HouseAge'], df['Population']], columns = ['HouseAge','Population'])
Y = df['PRICE']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 8, random_state=0)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
model = LinearRegression()
model.fit(X_train, Y_train)
model.intercept_
model.coef_
model.score(X_train, Y_train)
model.score(X_test, Y_test)
y_pred = model.predict(X_train)
mse = mean_squared_error(Y_train, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(Y_train, y_pred)
r2 = r2_score(Y_train, y_pred)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  PRICE
# ...
