# %% [markdown]
# <a href="https://colab.research.google.com/github/sagar1hh/cie-1/blob/main/CIE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/mtcars (2).csv')
plt.figure(figsize=(8,6))
plt.hist(df['mpg'],bins=10)
plt.title("Histogram of MPG")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/mtcars (2).csv')
plt.scatter(df['mpg'],df['wt'])
plt.title('Scatter Plot')
plt.xlabel('mpg')
plt.ylabel('wt')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.read_csv('/content/mtcars (2).csv')
trans_counts = df['am'].value_counts()
trans_counts.plot(kind='bar')
plt.title('Frequency ')
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/mtcars (2).csv')
plt.boxplot(df['mpg'])
plt.title("Boxplot")
plt.xlabel('MPG')
plt.show()
